# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen as uReq
import requests
import urllib
import os
import re
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
lem = WordNetLemmatizer()
nltk.data.path.append("C:\\Users\\PCLP\\AppData\\Roaming\\nltk_data")
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')

#C:\Users\PCLP\AppData\Roaming\nltk_data

stop_words = stopwords.words('english')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\PCLP\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\PCLP\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\PCLP\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
data=pd.read_excel('E:\\For_Job\\Blackcoffer\\Input.xlsx')

# %%
data.head()
# Out:
#             URL_ID                                                URL
# 0  blackassign0001  https://insights.blackcoffer.com/rising-it-cit...
# 1  blackassign0002  https://insights.blackcoffer.com/rising-it-cit...
# 2  blackassign0003  https://insights.blackcoffer.com/internet-dema...
# 3  blackassign0004  https://insights.blackcoffer.com/rise-of-cyber...
# 4  blackassign0005  https://insights.blackcoffer.com/ott-platform-...

# %%
for i in data['URL']:
    print(i)
# Out:
# https://insights.blackcoffer.com/rising-it-cities-and-its-impact-on-the-economy-environment-infrastructure-and-city-life-by-the-year-2040-2/
# https://insights.blackcoffer.com/rising-it-cities-and-their-impact-on-the-economy-environment-infrastructure-and-city-life-in-future/
# https://insights.blackcoffer.com/internet-demands-evolution-communication-impact-and-2035s-alternative-pathways/
# https://insights.blackcoffer.com/rise-of-cybercrime-and-its-effect-in-upcoming-future/
# https://insights.blackcoffer.com/ott-platform-and-its-impact-on-the-entertainment-industry-in-future/
# https://insights.blackcoffer.com/the-rise-of-the-ott-platform-and-its-impact-on-the-entertainment-industry-by-2040/
# https://insights.blackcoffer.com/rise-of-cyber-crime-and-its-effects/
# https://insights.blackcoffer.com/rise-of-internet-demand-and-its-impact-on-communications-and-alternatives-by-the-year-2035-2/
# https://insights.blackcoffer.com/rise-of-cybercrime-and-its-effect-by-the-year-2040-2/
# ...

# %%
#pip install openpyxl

# %%
url = 'https://insights.blackcoffer.com/rising-it-cities-and-its-impact-on-the-economy-environment-infrastructure-and-city-life-by-the-year-2040-2/'

# %%
#pip install requests

# %%
url
# Out:
# 'https://insights.blackcoffer.com/rising-it-cities-and-its-impact-on-the-economy-environment-infrastructure-and-city-life-by-the-year-2040-2/'

# %%
response_code=requests.get(url)

# %%
response_code
# Out:
# <Response [200]>

# %%
soup = bs(response_code.text,'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html >
#
# <!--[if IE 8]>    <html class="ie8" lang="en"> <![endif]-->
# <!--[if IE 9]>    <html class="ie9" lang="en"> <![endif]-->
# <!--[if gt IE 8]><!--> <html lang="en-US"> <!--<![endif]-->
# <head>
# <title>Rising IT cities and its impact on the economy, environment, infrastructure, and city life by the year 2040. - Blackcoffer Insights</title>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <link href="https://insights.blackcoffer.com/xmlrpc.php" rel="pingback"/>
# <meta content="index, follow, max-image-preview:large, max-snippet:-1, max-video-preview:-1" name="robots">
# <!-- This site is optimized with the Yoast SEO plugin v21.1 - https://yoast.com/wordpress/plugins/seo/ -->
# <link href="https://insights.blackcoffer.com/rising-it-cities-and-its-impact-on-the-economy-environment-infrastructure-and-city-life-by-the-year-2040-2/" rel="canonical"/>
# <meta content="en_US" property="og:locale"/>
# ...

# %%
article_title=soup.find('title').text

# %%
article_title
# Out:
# 'Rising IT cities and its impact on the economy, environment, infrastructure, and city life by the year 2040. - Blackcoffer Insights'

# %%
alldiv=soup.find("div", class_ = "td-post-content tagdiv-type").get_text(strip=True,separator='\n')

#all_text = soup.find('div', class_='td-post-content').get_text(strip=True,separator='\n')

# %%
len(alldiv)
# Out:
# 6973

# %%
alldiv
# Out:
# 'We have seen a huge development and dependence of people on technology in recent years. We have also seen the development of AI and ChatGPT in recent years. So it is a normal thing that we will become fully dependent on technology by 2040. Information technology will be a major power for all the developing nations. As a member of a developing nation, India is rapidly growing its IT base. It has also grown some IT cities which will be the major control centres for Information technology by 2040.\nRising IT cities\nNoida:-\nNoida in Uttar Pradesh near New Delhi is an emerging IT sector now. Many large companies like Google, Microsoft, IBM, Infosys and others have set up their companies here. Noida has a market base of billions of dollars and is doing a great job of boosting the national economy. The establishment of so many software companies has made Noida an information technology hub.\nGurgaon:-\nGurgaon in Haryana is also an emerging IT hub. Many large companies like Google, Micro
# ...

# %%
all_text = soup.find('div', class_='td-post-content').get_text(strip=True,separator='\n')

# %%
firstdata=all_text.splitlines()

# %%
firstdata
# Out:
# ['We have seen a huge development and dependence of people on technology in recent years. We have also seen the development of AI and ChatGPT in recent years. So it is a normal thing that we will become fully dependent on technology by 2040. Information technology will be a major power for all the developing nations. As a member of a developing nation, India is rapidly growing its IT base. It has also grown some IT cities which will be the major control centres for Information technology by 2040.',
#  'Rising IT cities',
#  'Noida:-',
#  'Noida in Uttar Pradesh near New Delhi is an emerging IT sector now. Many large companies like Google, Microsoft, IBM, Infosys and others have set up their companies here. Noida has a market base of billions of dollars and is doing a great job of boosting the national economy. The establishment of so many software companies has made Noida an information technology hub.',
#  'Gurgaon:-',
# ...

# %%
filename = urllib.parse.quote_plus(url)

# %%
file_path = 'E:\For_Job\Blackcoffer\Code\Text_files'

# %%
space = " "

# %%
file1 = open(f"{file_path}\{filename}.txt",'w+')
file1.writelines(article_title)
file1.writelines(space)
file1.writelines(firstdata)
file1.read()
# Out:
# ''

# %%
file1.seek(0)
m=file1.readlines()

# %%
m
# Out:
# ['Rising IT cities and its impact on the economy, environment, infrastructure, and city life by the year 2040. - Blackcoffer Insights We have seen a huge development and dependence of people on technology in recent years. We have also seen the development of AI and ChatGPT in recent years. So it is a normal thing that we will become fully dependent on technology by 2040. Information technology will be a major power for all the developing nations. As a member of a developing nation, India is rapidly growing its IT base. It has also grown some IT cities which will be the major control centres for Information technology by 2040.Rising IT citiesNoida:-Noida in Uttar Pradesh near New Delhi is an emerging IT sector now. Many large companies like Google, Microsoft, IBM, Infosys and others have set up their companies here. Noida has a market base of billions of dollars and is doing a great job of boosting the national economy. The establishment of so many software companies has made Noida an
# ...

# %%
import nltk
import re
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\PCLP\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
stopwords.words('english')
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
# ...

# %%
a = ''
for i in m:
    print(i)
    a = i
# Out:
# Rising IT cities and its impact on the economy, environment, infrastructure, and city life by the year 2040. - Blackcoffer Insights We have seen a huge development and dependence of people on technology in recent years. We have also seen the development of AI and ChatGPT in recent years. So it is a normal thing that we will become fully dependent on technology by 2040. Information technology will be a major power for all the developing nations. As a member of a developing nation, India is rapidly growing its IT base. It has also grown some IT cities which will be the major control centres for Information technology by 2040.Rising IT citiesNoida:-Noida in Uttar Pradesh near New Delhi is an emerging IT sector now. Many large companies like Google, Microsoft, IBM, Infosys and others have set up their companies here. Noida has a market base of billions of dollars and is doing a great job of boosting the national economy. The establishment of so many software companies has made Noida an i
# ...

# %%
a
# Out:
# 'Rising IT cities and its impact on the economy, environment, infrastructure, and city life by the year 2040. - Blackcoffer Insights We have seen a huge development and dependence of people on technology in recent years. We have also seen the development of AI and ChatGPT in recent years. So it is a normal thing that we will become fully dependent on technology by 2040. Information technology will be a major power for all the developing nations. As a member of a developing nation, India is rapidly growing its IT base. It has also grown some IT cities which will be the major control centres for Information technology by 2040.Rising IT citiesNoida:-Noida in Uttar Pradesh near New Delhi is an emerging IT sector now. Many large companies like Google, Microsoft, IBM, Infosys and others have set up their companies here. Noida has a market base of billions of dollars and is doing a great job of boosting the national economy. The establishment of so many software companies has made Noida an 
# ...

# %% [markdown]
# ### 1	Sentimental Analysis

# %%
"""url = 'https://insights.blackcoffer.com/rise-of-e-health-and-its-imapct-on-humans-by-the-year-2030-2/'
response_code = requests.get(url)
soup = bs(response_code.text, 'html.parser')
article_title = soup.find('title').text

# Find the element with the specified class
alldiv_element = soup.find("div", class_="td_block_wrap tdb_single_content tdi_130 td-pb-border-top td_block_template_1 td-post-content tagdiv-type").get_text(strip=True, separator='\n')

# Check if the element exists

if alldiv_element:
    alldiv = alldiv_element.get_text(strip=True, separator='\n')
else:
    print(f"No matching element found for URL: {url}")
    alldiv = ""
  

# Print or use the 'alldiv' variable as needed
print(alldiv)
"""
# Out:
# We have seen a huge development and dependence of people on technology in recent years. We have also seen the development of AI and ChatGPT in recent years. So it is a normal thing that we will become fully dependent on technology by 2040. Information technology will be a major power for all the developing nations. As a member of a developing nation, India is rapidly growing its IT base. It has also grown some IT cities which will be the major control centres for Information technology by 2040.
# Rising IT cities
# Noida:-
# Noida in Uttar Pradesh near New Delhi is an emerging IT sector now. Many large companies like Google, Microsoft, IBM, Infosys and others have set up their companies here. Noida has a market base of billions of dollars and is doing a great job of boosting the national economy. The establishment of so many software companies has made Noida an information technology hub.
# Gurgaon:-
# ...

# %%
Blank_link = {}
class data_ingestion:    
            
    def secondary(self):
        data = pd.read_excel('E:\\For_Job\\Blackcoffer\\Code\\Notebook\\data\\Input.xlsx')
        df = data.copy()  # Create a copy to avoid modifying the original DataFrame
        
        # Create an empty 'article_words' column
        df['article_words'] = ''
        
        for i, url in enumerate(df['URL']):
            response_code = requests.get(url)
            soup = bs(response_code.text, 'html.parser')
            article_title = soup.find('title').text
            
            all_text_element = soup.find("div", class_="td-post-content tagdiv-type")

            if all_text_element is not None:
                all_text = all_text_element.get_text(strip=True, separator='\n')
                firstdata = all_text.splitlines()
            else:
                print(f"No matching element found in the HTML for URL: {url}")
                Blank_link[f"blackassign00{i+1}"] = url
                firstdata = []
                """for i, j in Blank_link.items():
                    if url == j:
                        response_code=requests.get(j)
                        soup = bs(response_code.text,'html.parser')
                        article_title=soup.find('title').text
                        alldiv=soup.find("div", class_ = "td_block_wrap tdb_single_content tdi_130 td-pb-border-top td_block_template_1 td-post-content tagdiv-type")#.get_text(strip=True,separator='\n')
                        firstdata=alldiv.text
                        return firstdata
                    else:
                        print(f"No matching element found in the HTML for URL: {url}")"""
                        
                

            filename = urllib.parse.quote_plus(url)
            file_path = 'E:\For_Job\Blackcoffer\Code\Text_files'
            space = " "
                
            with open(f"{file_path}\{filename}.txt", 'w+') as file1:
                file1.writelines(article_title)
                file1.writelines(space)
                file1.writelines(firstdata)
                
            # Update 'article_words' column for the current row
            df.at[i, 'article_words'] = f"{article_title}-{firstdata}"

        df.to_csv('E:\\For_Job\\Blackcoffer\\Code\\Notebook\\data\\final.csv', index=False)
        return df
                
if __name__ == "__main__":
    obj = data_ingestion()
    obj.secondary()
# Out:
# No matching element found in the HTML for URL: https://insights.blackcoffer.com/how-covid-19-is-impacting-payment-preferences/
# No matching element found in the HTML for URL: https://insights.blackcoffer.com/how-will-covid-19-affect-the-world-of-work-2/

# %%
df.columns
# Out:
# Index(['URL_ID', 'URL', 'article_words'], dtype='object')

# %%
Blank_link
# Out:
# {'blackassign008': 'https://insights.blackcoffer.com/how-covid-19-is-impacting-payment-preferences/',
#  'blackassign009': 'https://insights.blackcoffer.com/how-will-covid-19-affect-the-world-of-work-2/'}

# %%
#Blank_link = {}
#updated_list = []
class data_ingestion:    
            
    def secondary(self):
        data = pd.read_excel('E:\\For_Job\\Blackcoffer\\Code\\Notebook\\data\\Input.xlsx')
        df = data.copy()  # Create a copy to avoid modifying the original DataFrame
        col = df.columns
        Blank_link = {}
        updated_list = []
          
        # Create an empty 'article_words' column
        df['article_words'] = ''
        
        for i, url in enumerate(df['URL']):
            response_code = requests.get(url)
            soup = bs(response_code.text, 'html.parser')
            article_title = soup.find('title').text
            
            all_text_element = soup.find("div", class_="td-post-content tagdiv-type")

            if all_text_element is not None:
                all_text = all_text_element.get_text(strip=True, separator='\n')
                firstdata = all_text.splitlines()
            else:
                #print(f"No matching element found in the HTML for URL: {url}")
                Blank_link[f"blackassign00{i+1}"] = url
                firstdata = []
                
                if firstdata is None:
                    response_code = requests.get(url)
                    soup = bs(response_code.text, 'html.parser')
                    article_title = soup.find('title').text
                    
                    alldiv = soup.find("div", class_="td_block_wrap tdb_single_content tdi_130 td-pb-border-top td_block_template_1 td-post-content tagdiv-type")

                    if alldiv is not None:
                        firstdata = alldiv.text
                        
                        filename = urllib.parse.quote_plus(j)
                        file_path = 'E:\For_Job\Blackcoffer\Code\Text_files'
                        space = " "
                            
                        with open(f"{file_path}\{filename}.txt", 'w+') as file1:
                            file1.writelines(article_title)
                            file1.writelines(space)
                            file1.writelines(firstdata)
                
                
                else:
                    print(f"No matching element found in the HTML for URL: {url}")
                        
            new_dataframe = {
                    "URL_ID": df["URL_ID"][i],
                    'URL' : url,
                    'article_words':f"{article_title}-{firstdata}"
                }    
            
            updated_list.append(new_dataframe)

            filename = urllib.parse.quote_plus(url)
            file_path = 'E:\For_Job\Blackcoffer\Code\Text_files'
            space = " "
                
            with open(f"{file_path}\{filename}.txt", 'w+') as file1:
                file1.writelines(article_title)
                file1.writelines(space)
                file1.writelines(firstdata)
                
            # Update 'article_words' column for the current row
            df.at[i, 'article_words'] = f"{article_title}-{firstdata}"

        df.to_csv('E:\\For_Job\\Blackcoffer\\Code\\Notebook\\data\\final.csv', index=False)
        
        return updated_list,Blank_link
                
if __name__ == "__main__":
    obj = data_ingestion()
    a,b=obj.secondary()
# Out:
# No matching element found in the HTML for URL: https://insights.blackcoffer.com/how-will-covid-19-affect-the-world-of-work-2/

# %%
a
# Out:
# [{'URL_ID': 'blackassign0001',
#   'URL': 'https://insights.blackcoffer.com/rising-it-cities-and-its-impact-on-the-economy-environment-infrastructure-and-city-life-by-the-year-2040-2/',
# ...

# %%
b.items()
# Out:
# {'blackassign008': 'https://insights.blackcoffer.com/how-will-covid-19-affect-the-world-of-work-2/'}

# %%
#unmacting_data = []
#unmacting_data.append(Blank_link)

pd.DataFrame([Blank_link])
# Out:
#                                       blackassign008  \
# 0  https://insights.blackcoffer.com/how-covid-19-...
#
#                                       blackassign009
# 0  https://insights.blackcoffer.com/how-will-covi...

# %%
updated_list = []

for i, j in Blank_link.items():
    response_code = requests.get(j)
    soup = bs(response_code.text, 'html.parser')
    article_title = soup.find('title').text
    
    alldiv = soup.find("div", class_="td_block_wrap tdb_single_content tdi_130 td-pb-border-top td_block_template_1 td-post-content tagdiv-type")

    if alldiv is not None:
        firstdata = alldiv.text
        
        filename = urllib.parse.quote_plus(j)
        file_path = 'E:\For_Job\Blackcoffer\Code\Text_files'
        space = " "
            
        with open(f"{file_path}\{filename}.txt", 'w+') as file1:
            file1.writelines(article_title)
            file1.writelines(space)
            file1.writelines(firstdata)
        
       
        updated_dict = {
            'URL_ID': i,
            'URL': j,
            'article_words': f"{article_title} - {firstdata}"
        }
        
        
        updated_list.append(updated_dict)
        
    else:
        print(f"No data available for the link: {j}")


updated_df = pd.DataFrame(updated_list)

# %%
remain_data=pd.DataFrame(updated_df)

# %%
#remain_data.drop(columns='URL_ID',axis=1,inplace=True)

# %%
remain_data
# Out:
#            URL_ID                                                URL  \
# 0  blackassign008  https://insights.blackcoffer.com/how-covid-19-...
# 1  blackassign009  https://insights.blackcoffer.com/how-will-covi...
#
#                                        article_words
# 0  How COVID-19 is impacting payment preferences?...
# 1  How will COVID-19 affect the world of work? - ...

# %%
#df = pd.merge(df, updated_df[['URL', 'article_words']], on='URL', how='left')

# %%
df.head()
# Out:
#             URL_ID                                                URL  \
# 0  blackassign0001  https://insights.blackcoffer.com/rising-it-cit...
# 1  blackassign0002  https://insights.blackcoffer.com/rising-it-cit...
# 2  blackassign0003  https://insights.blackcoffer.com/internet-dema...
# 3  blackassign0004  https://insights.blackcoffer.com/rise-of-cyber...
# 4  blackassign0005  https://insights.blackcoffer.com/ott-platform-...
#
#                                        article_words
# 0  Rising IT cities and its impact on the economy...
# 1  Rising IT Cities and Their Impact on the Econo...
# 2  Internet Demand's Evolution, Communication Imp...
# 3  Rise of Cybercrime and its Effect in upcoming ...
# 4  OTT platform and its impact on the entertainme...

# %%
remain_data.to_csv('E:\\For_Job\\Blackcoffer\\Code\\Notebook\\data\\remain_data.csv')

# %%
remain_data.head(20)
# Out:
#              URL_ID                                                URL  \
# 0   blackassign0014  https://insights.blackcoffer.com/rise-of-e-hea...
# 1   blackassign0020  https://insights.blackcoffer.com/how-advertise...
# 2   blackassign0029  https://insights.blackcoffer.com/ai-in-healthc...
# 3   blackassign0043  https://insights.blackcoffer.com/future-of-wor...
# 4   blackassign0083  https://insights.blackcoffer.com/human-rights-...
# 5   blackassign0084  https://insights.blackcoffer.com/how-voice-sea...
# 6   blackassign0092  https://insights.blackcoffer.com/estimating-th...
# 7   blackassign0099  https://insights.blackcoffer.com/how-covid-19-...
# 8  blackassign00100  https://insights.blackcoffer.com/how-will-covi...
#
#                                        article_words
# 0  Rise of e-health and its impact on humans by t...
# 1  How advertisement increase your market value? ...
# 2  AI in healthcare to Improve Patient Outcomes -...
# ...

# %%
df.head(20)
# Out:
#                                                                URL  \
# URL_ID
# blackassign0001  https://insights.blackcoffer.com/rising-it-cit...
# blackassign0002  https://insights.blackcoffer.com/rising-it-cit...
# blackassign0003  https://insights.blackcoffer.com/internet-dema...
# blackassign0004  https://insights.blackcoffer.com/rise-of-cyber...
# blackassign0005  https://insights.blackcoffer.com/ott-platform-...
# blackassign0006  https://insights.blackcoffer.com/the-rise-of-t...
# blackassign0007  https://insights.blackcoffer.com/rise-of-cyber...
# blackassign0008  https://insights.blackcoffer.com/rise-of-inter...
# blackassign0009  https://insights.blackcoffer.com/rise-of-cyber...
# blackassign0010  https://insights.blackcoffer.com/rise-of-cyber...
# blackassign0011  https://insights.blackcoffer.com/rise-of-inter...
# blackassign0012  https://insights.blackcoffer.com/rise-of-telem...
# blackassign0013  https://insights.blackcoffer.com/rise-of-e-hea...
# ...

# %%
remain_data.set_index('URL_ID',inplace=True)
df.set_index('URL_ID',inplace=True)

# %%
df.head()
# Out:
#                                                                URL  \
# URL_ID
# blackassign0001  https://insights.blackcoffer.com/rising-it-cit...
# blackassign0002  https://insights.blackcoffer.com/rising-it-cit...
# blackassign0003  https://insights.blackcoffer.com/internet-dema...
# blackassign0004  https://insights.blackcoffer.com/rise-of-cyber...
# blackassign0005  https://insights.blackcoffer.com/ott-platform-...
#
#                                                      article_words
# URL_ID
# blackassign0001  Rising IT cities and its impact on the economy...
# blackassign0002  Rising IT Cities and Their Impact on the Econo...
# blackassign0003  Internet Demand's Evolution, Communication Imp...
# blackassign0004  Rise of Cybercrime and its Effect in upcoming ...
# blackassign0005  OTT platform and its impact on the entertainme...

# %%
remain_data.head()
# Out:
#                                                                URL  \
# URL_ID
# blackassign0014  https://insights.blackcoffer.com/rise-of-e-hea...
# blackassign0020  https://insights.blackcoffer.com/how-advertise...
# blackassign0029  https://insights.blackcoffer.com/ai-in-healthc...
# blackassign0043  https://insights.blackcoffer.com/future-of-wor...
# blackassign0083  https://insights.blackcoffer.com/human-rights-...
#
#                                                      article_words
# URL_ID
# blackassign0014  Rise of e-health and its impact on humans by t...
# blackassign0020  How advertisement increase your market value? ...
# blackassign0029  AI in healthcare to Improve Patient Outcomes -...
# blackassign0043  Future of Work: How AI Has Entered the Workpla...
# blackassign0083  Human Rights Outlook - Blackcoffer Insights - ...

# %%
df_data=df.combine_first(remain_data)

# %%
df_data.reset_index()
# Out:
#              URL_ID                                                URL  \
# 0   blackassign0001  https://insights.blackcoffer.com/rising-it-cit...
# 1   blackassign0002  https://insights.blackcoffer.com/rising-it-cit...
# 2   blackassign0003  https://insights.blackcoffer.com/internet-dema...
# 3   blackassign0004  https://insights.blackcoffer.com/rise-of-cyber...
# 4   blackassign0005  https://insights.blackcoffer.com/ott-platform-...
# ..              ...                                                ...
# 94  blackassign0096  https://insights.blackcoffer.com/what-is-the-r...
# 95  blackassign0097  https://insights.blackcoffer.com/impact-of-cov...
# 96  blackassign0098  https://insights.blackcoffer.com/contribution-...
# 97  blackassign0099  https://insights.blackcoffer.com/how-covid-19-...
# 98  blackassign0100  https://insights.blackcoffer.com/how-will-covi...
#
#                                         article_words
# 0   Rising IT cities and its impact on the economy...
# ...

# %%
df_data.to_csv("E:\\For_Job\\Blackcoffer\\Code\\Notebook\\data\\Article_data.csv")

# %% [markdown]
# ### Text analysis|

# %%
df=pd.read_csv('E:\\For_Job\\Blackcoffer\\Code\\Notebook\\data\\Article_data.csv')

# %%
df.shape
# Out:
# (99, 3)

# %%
df
# Out:
#              URL_ID                                                URL  \
# 0   blackassign0001  https://insights.blackcoffer.com/rising-it-cit...
# 1   blackassign0002  https://insights.blackcoffer.com/rising-it-cit...
# 2   blackassign0003  https://insights.blackcoffer.com/internet-dema...
# 3   blackassign0004  https://insights.blackcoffer.com/rise-of-cyber...
# 4   blackassign0005  https://insights.blackcoffer.com/ott-platform-...
# ..              ...                                                ...
# 94  blackassign0096  https://insights.blackcoffer.com/what-is-the-r...
# 95  blackassign0097  https://insights.blackcoffer.com/impact-of-cov...
# 96  blackassign0098  https://insights.blackcoffer.com/contribution-...
# 97  blackassign0099  https://insights.blackcoffer.com/how-covid-19-...
# 98  blackassign0100  https://insights.blackcoffer.com/how-will-covi...
#
#                                         article_words
# 0   Rising IT cities and its impact on the economy...
# ...

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
lem = WordNetLemmatizer()

nltk.data.path.append("C:\\Users\\PCLP\\AppData\\Roaming\\nltk_data")
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')

#C:\Users\PCLP\AppData\Roaming\nltk_data

stop_words = stopwords.words('english')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\PCLP\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\PCLP\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\PCLP\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
stopword_auditor=open('E:\\For_Job\\Blackcoffer\\StopWords\\StopWords_Auditor.txt' ,'r',encoding='ISO-8859-1')
StopWords_Currencies=open('E:\\For_Job\\Blackcoffer\\StopWords\\StopWords_Currencies.txt' ,'r',encoding='ISO-8859-1')
StopWords_DatesandNumbers=open('E:\\For_Job\\Blackcoffer\\StopWords\\StopWords_DatesandNumbers.txt' ,'r',encoding='ISO-8859-1')
StopWords_Generic=open('E:\\For_Job\\Blackcoffer\\StopWords\\StopWords_Generic.txt' ,'r',encoding='ISO-8859-1')
StopWords_GenericLong=open('E:\\For_Job\\Blackcoffer\\StopWords\\StopWords_GenericLong.txt' ,'r',encoding='ISO-8859-1')
StopWords_Geographic=open('E:\\For_Job\\Blackcoffer\\StopWords\\StopWords_Geographic.txt' ,'r',encoding='ISO-8859-1')
StopWords_Names=open('E:\\For_Job\\Blackcoffer\\StopWords\\StopWords_Names.txt' ,'r',encoding='ISO-8859-1')

# %%
stopword_auditor.seek(0)
stopword_auditor.readlines()
# Out:
# ['ERNST\n',
#  'YOUNG\n',
#  'DELOITTE\n',
#  'TOUCHE\n',
#  'KPMG\n',
#  'PRICEWATERHOUSECOOPERS\n',
#  'PRICEWATERHOUSE\n',
#  'COOPERS\n']

# %% [markdown]
# ## Tokenized and Lemminatized the Text

# %%
"""def text_corpus(x):
    string_format = str(x).lower()
    lower_words=re.sub('[^a-zA-Z]+',' ',string_format).strip()
    #lower_words = lower_words.split()
    token = word_tokenize(lower_words)
    token_word = [t for t in token if t not in stop_words ]
    lemantizzed = [lem.lemmatize(w) for w in token_word]
    return lemantizzed"""
# Out:
# "def text_corpus(x):\n    string_format = str(x).lower()\n    lower_words=re.sub('[^a-zA-Z]+',' ',string_format).strip()\n    #lower_words = lower_words.split()\n    token = word_tokenize(lower_words)\n    token_word = [t for t in token if t not in stop_words ]\n    lemantizzed = [lem.lemmatize(w) for w in token_word]\n    return lemantizzed"

# %%
def text_corpus(x):
    string_format = str(x).lower()
    lower_words=re.sub('[^a-zA-Z]+',' ',string_format).strip()
    #lower_words = lower_words.split()
    token = word_tokenize(lower_words)
    token_word = [t for t in token if t not in (stopword_auditor,StopWords_Currencies,StopWords_DatesandNumbers,StopWords_Generic,StopWords_GenericLong,StopWords_Geographic,StopWords_Names) ]
    lemantizzed = [lem.lemmatize(w) for w in token_word]
    return lemantizzed

# %%
preprocessed_word = text_corpus(df['article_words'][10])

# %%
preprocessed_word
# Out:
# ['how',
#  'will',
#  'covid',
#  'affect',
#  'the',
#  'world',
#  'of',
#  'work',
#  'blackcoffer',
#  'insight',
#  'a',
#  'business',
#  'close',
#  'to',
#  'help',
#  'prevent',
#  'transmission',
#  'of',
#  'covid',
#  'financial',
#  'concern',
#  'and',
#  'job',
#  'loss',
#  'are',
#  'one',
#  'of',
#  'the',
#  'first',
#  'human',
#  'impact',
#  'of',
#  'the',
#  'virus',
#  'not',
#  'knowing',
#  'how',
#  'this',
#  'pandemic',
#  'will',
#  'play',
#  'out',
#  'also',
#  'affect',
#  'our',
#  'economic',
#  'physical',
#  'and',
#  'mental',
#  'well',
#  'being',
#  'despite',
#  'this',
#  'fear',
#  'business',
#  'and',
#  'community',
#  'in',
#  'many',
#  'region',
#  'have',
#  'shown',
#  'a',
#  'more',
#  'altruistic',
#  'response',
#  'in',
#  'the',
#  'face',
#  'of',
#  'crisis',
#  'action',
#  'which',
#  'could',
#  'help',
#  'country',
#  'preparing',
#  'for',
#  'covid',
#  'covid',
#  'is',
#  'in',
#  'decline',
#  'in',
#  'china',
# ...

# %%
len(preprocessed_word)
# Out:
# 1057

# %%
file_neg = open('E:\\For_Job\\Blackcoffer\\MasterDictionary\\negative-words.txt' ,'r',encoding='ISO-8859-1')
file_neg.seek(0)
neg_split = file_neg.read().split()
len(neg_split)
# Out:
# 4783

# %%
file_pos = open('E:\\For_Job\\Blackcoffer\\MasterDictionary\\positive-words.txt' ,'r',encoding='ISO-8859-1')
file_pos.seek(0)
pos_split = file_pos.read().split()
len(pos_split)
# Out:
# 2006

# %%
neg_split
# Out:
# ['2-faced',
#  '2-faces',
#  'abnormal',
#  'abolish',
#  'abominable',
#  'abominably',
#  'abominate',
#  'abomination',
#  'abort',
#  'aborted',
#  'aborts',
#  'abrade',
#  'abrasive',
#  'abrupt',
#  'abruptly',
#  'abscond',
#  'absence',
#  'absent-minded',
#  'absentee',
#  'absurd',
#  'absurdity',
#  'absurdly',
#  'absurdness',
#  'abuse',
#  'abused',
#  'abuses',
#  'abusive',
#  'abysmal',
#  'abysmally',
#  'abyss',
#  'accidental',
#  'accost',
#  'accursed',
#  'accusation',
#  'accusations',
#  'accuse',
#  'accuses',
#  'accusing',
#  'accusingly',
#  'acerbate',
#  'acerbic',
#  'acerbically',
#  'ache',
#  'ached',
#  'aches',
#  'achey',
#  'aching',
#  'acrid',
#  'acridly',
#  'acridness',
#  'acrimonious',
#  'acrimoniously',
#  'acrimony',
#  'adamant',
#  'adamantly',
#  'addict',
#  'addicted',
#  'addicting',
#  'addicts',
#  'admonish',
#  'admonisher',
#  'admonishingly',
#  'admonishment',
#  'admonition',
#  'adulterate',
#  'adulterated',
# ...

# %%
pos_split
# Out:
# ['a+',
#  'abound',
#  'abounds',
#  'abundance',
#  'abundant',
#  'accessable',
#  'accessible',
#  'acclaim',
#  'acclaimed',
#  'acclamation',
#  'accolade',
#  'accolades',
#  'accommodative',
#  'accomodative',
#  'accomplish',
#  'accomplished',
#  'accomplishment',
#  'accomplishments',
#  'accurate',
#  'accurately',
#  'achievable',
#  'achievement',
#  'achievements',
#  'achievible',
#  'acumen',
#  'adaptable',
#  'adaptive',
#  'adequate',
#  'adjustable',
#  'admirable',
#  'admirably',
#  'admiration',
#  'admire',
#  'admirer',
#  'admiring',
#  'admiringly',
#  'adorable',
#  'adore',
#  'adored',
#  'adorer',
#  'adoring',
#  'adoringly',
#  'adroit',
#  'adroitly',
#  'adulate',
#  'adulation',
#  'adulatory',
#  'advanced',
#  'advantage',
#  'advantageous',
#  'advantageously',
#  'advantages',
#  'adventuresome',
#  'adventurous',
#  'advocate',
#  'advocated',
#  'advocates',
#  'affability',
#  'affable',
#  'affably',
#  'affectation',
#  'affection',
# ...

# %%
len(preprocessed_word)
# Out:
# 1057

# %%
neg_count = []
for i in preprocessed_word:
    if i in neg_split:
        neg_count.append(i)
              
            
            
len(neg_count)
#neg_count
# Out:
# 62

# %%
pos_count = []
for i in preprocessed_word:
    if i in pos_split:
        pos_count.append(i)
        
              
            
            
len(pos_count)
#pos_count
# Out:
# 40

# %%
"""
path = 'E:\For_Job\Blackcoffer\Code\Dictionaries'
file_name = 'negative_dictionary'
neg_dict=open(f'{path}\{file_name}.txt','w+')

neg_dict.write()
neg_dict.write(space)
"""
# Out:
# "\npath = 'E:\\For_Job\\Blackcoffer\\Code\\Dictionaries'\nfile_name = 'negative_dictionary'\nneg_dict=open(f'{path}\\{file_name}.txt','w+')\n\nneg_dict.write()\nneg_dict.write(space)\n"

# %% [markdown]
# #### Positive score , Negative Score , Polarity Score , Subjective Score

# %%
len(preprocessed_word)
# Out:
# 1057

# %%
neg_score = len(neg_count)
pos_score = len(pos_count)

# %% [markdown]
# #### 3.	NEGATIVE SCORE

# %%
neg_score
# Out:
# 62

# %% [markdown]
# #### 2.	POSITIVE SCORE

# %%
pos_score
# Out:
# 40

# %% [markdown]
# #### 4.	POLARITY SCORE

# %%
polarity_score = (pos_score - neg_score)/ ((pos_score + neg_score) + 0.000001 )

# %%
polarity_score
# Out:
# -0.21568627239523264

# %% [markdown]
# #### 5.	SUBJECTIVITY SCORE

# %%
subjective_score = (pos_score + neg_score)/ ((len(preprocessed_word)) + 0.000001 )

# %%
subjective_score
# Out:
# 0.09649952687180743

# %% [markdown]
# #### Total Sentenses

# %%
#total_words =nltk.tokenize.word_tokenize(df['article_words'][10])

total_words = len(preprocessed_word)

# %% [markdown]
# #### 6.	AVG SENTENCE LENGTH

# %%
total_sentences =len(nltk.tokenize.sent_tokenize(df['article_words'][10]))

# %%
nltk.tokenize.sent_tokenize(df['article_words'][10])
# Out:
# ['How will COVID-19 affect the world of work?',
#  '- Blackcoffer Insights - \n\nAs business close to help prevent transmission of COVID-19, financial concerns and job losses are one of the first human impacts of the virus;\nNot knowing how this pandemic will play out also affects our economic, physical and mental well-being;Despite this fear, businesses and communities in many regions have shown a more altruistic response in the face of crisis – actions which could help countries preparing for COVID-19.',
#  'COVID-19 is in decline in China.',
#  'There are now more new cases every day in Europe than there were in China at the epidemic’s peak and Italy has surpassed it as the country with the most deaths from the virus It took 67 days to reach the first 100,000 confirmed cases worldwide, 11 days for this to increase to 200,000and just four to reach 300,000 confirmed cases – a figure now exceeded.',
# ...

# %%
len(df['article_words'][10].split())
# Out:
# 1048

# %%
nltk.word_tokenize(df['article_words'][10])
# Out:
# ['How',
#  'will',
#  'COVID-19',
#  'affect',
#  'the',
#  'world',
#  'of',
#  'work',
#  '?',
#  '-',
#  'Blackcoffer',
#  'Insights',
#  '-',
#  'As',
#  'business',
#  'close',
#  'to',
#  'help',
#  'prevent',
#  'transmission',
#  'of',
#  'COVID-19',
#  ',',
#  'financial',
#  'concerns',
#  'and',
#  'job',
#  'losses',
#  'are',
#  'one',
#  'of',
#  'the',
#  'first',
#  'human',
#  'impacts',
#  'of',
#  'the',
#  'virus',
#  ';',
#  'Not',
#  'knowing',
#  'how',
#  'this',
#  'pandemic',
#  'will',
#  'play',
#  'out',
#  'also',
#  'affects',
#  'our',
#  'economic',
#  ',',
#  'physical',
#  'and',
#  'mental',
#  'well-being',
#  ';',
#  'Despite',
#  'this',
#  'fear',
#  ',',
#  'businesses',
#  'and',
#  'communities',
#  'in',
#  'many',
#  'regions',
#  'have',
#  'shown',
#  'a',
#  'more',
#  'altruistic',
#  'response',
#  'in',
#  'the',
#  'face',
#  'of',
#  'crisis',
#  '–',
#  'actions',
#  'which',
#  'could',
#  'help',
#  'countries',
#  'preparing',
# ...

# %%
total_sentences
# Out:
# 33

# %%
total_words
# Out:
# 1057

# %%
Average_Sentence_Length = round(total_words/total_sentences,0)

# %%
Average_Sentence_Length
# Out:
# 32.0

# %% [markdown]
# #### 7.	PERCENTAGE OF COMPLEX WORDS AND 10.	COMPLEX WORD COUNT

# %%
def count_syllables(word):
    vowels = ("a","e","i","o","u","y")
    count = 0
    previous_char_was_vowel = False

    for char in word:
        if char in vowels:
            if not previous_char_was_vowel:
                count += 1
            previous_char_was_vowel = True
        else:
            previous_char_was_vowel = False

    return count

def calculate_complexity_percentage(words):
    #words = text.split()
    num_complex_words = sum(1 for word in words if count_syllables(word) >= 2)
    total_words = len(words)
    no_of_complex_words = num_complex_words 
    percentage_complex_words = (num_complex_words / total_words) * 100
    return percentage_complex_words,no_of_complex_words

# %%
Percentage_of_Complex_words,total_num_of_complex_words_count = calculate_complexity_percentage(preprocessed_word)

# %%
Percentage_of_Complex_words
# Out:
# 50.709555345316936

# %%
total_num_of_complex_words_count
# Out:
# 536

# %% [markdown]
# #### 8.	FOG INDEX

# %%
FOG_Index = 0.4*(Average_Sentence_Length + Percentage_of_Complex_words)

# %%
FOG_Index
# Out:
# 33.08382213812678

# %% [markdown]
# #### 9.	AVG NUMBER OF WORDS PER SENTENCE

# %%
Average_Number_of_Words_Per_Sentence=round(len(df["article_words"][10])/total_sentences,0)

# %%
df["article_words"][10].split()
# Out:
# ['How',
#  'will',
#  'COVID-19',
#  'affect',
#  'the',
#  'world',
#  'of',
#  'work?',
#  '-',
#  'Blackcoffer',
#  'Insights',
#  '-',
#  'As',
#  'business',
#  'close',
#  'to',
#  'help',
#  'prevent',
#  'transmission',
#  'of',
#  'COVID-19,',
#  'financial',
#  'concerns',
#  'and',
#  'job',
#  'losses',
#  'are',
#  'one',
#  'of',
#  'the',
#  'first',
#  'human',
#  'impacts',
#  'of',
#  'the',
#  'virus;',
#  'Not',
#  'knowing',
#  'how',
#  'this',
#  'pandemic',
#  'will',
#  'play',
#  'out',
#  'also',
#  'affects',
#  'our',
#  'economic,',
#  'physical',
#  'and',
#  'mental',
#  'well-being;Despite',
#  'this',
#  'fear,',
#  'businesses',
#  'and',
#  'communities',
#  'in',
#  'many',
#  'regions',
#  'have',
#  'shown',
#  'a',
#  'more',
#  'altruistic',
#  'response',
#  'in',
#  'the',
#  'face',
#  'of',
#  'crisis',
#  '–',
#  'actions',
#  'which',
#  'could',
#  'help',
#  'countries',
#  'preparing',
#  'for',
#  'COVID-19.',
#  'COVID-19',
# ...

# %%
Average_Number_of_Words_Per_Sentence
# Out:
# 206.0

# %% [markdown]
# #### 11.	WORD COUNT

# %%
Word_Count = len(preprocessed_word)

# %%
Word_Count
# Out:
# 1057

# %% [markdown]
# #### Syllable Per Words

# %%
def count_syllables(word):
    vowels = "aeiouy"
    exceptions = ["es", "ed"]
    count = 0
    previous_char_was_vowel = False

    for exception in exceptions:
        if word.endswith(exception):
            return 0  


    for char in word.lower():
        if char in vowels:
            if not previous_char_was_vowel:
                count += 1
            previous_char_was_vowel = True
        else:
            previous_char_was_vowel = False

    return count

def count_syllables_per_word(words):
    syllables_per_word = {word: count_syllables(word) for word in words}
    return syllables_per_word
# Out:
# {'how': 1,
#  'will': 1,
#  'covid': 2,
#  'affect': 2,
#  'the': 1,
#  'world': 1,
#  'of': 1,
#  'work': 1,
#  'blackcoffer': 3,
#  'insight': 2,
#  'a': 1,
#  'business': 3,
#  'close': 2,
#  'to': 1,
#  'help': 1,
#  'prevent': 2,
#  'transmission': 3,
#  'financial': 3,
#  'concern': 2,
#  'and': 1,
#  'job': 1,
#  'loss': 1,
#  'are': 2,
#  'one': 2,
#  'first': 1,
#  'human': 2,
#  'impact': 2,
#  'virus': 2,
#  'not': 1,
#  'knowing': 2,
#  'this': 1,
#  'pandemic': 3,
#  'play': 1,
#  'out': 1,
#  'also': 2,
#  'our': 1,
#  'economic': 4,
#  'physical': 3,
#  'mental': 2,
#  'well': 1,
#  'being': 1,
#  'despite': 3,
#  'fear': 1,
#  'community': 4,
#  'in': 1,
#  'many': 2,
#  'region': 2,
#  'have': 2,
#  'shown': 1,
#  'more': 2,
#  'altruistic': 3,
#  'response': 3,
#  'face': 2,
#  'crisis': 2,
#  'action': 2,
#  'which': 1,
#  'could': 1,
#  'country': 2,
#  'preparing': 3,
#  'for': 1,
#  'is': 1,
#  'decline': 3,
#  'china': 2,
#  'there': 2,
#  'now': 1,
# ...

# %%
syllables_per_word
# Out:
# {'how': 1,
#  'will': 1,
#  'covid': 2,
#  'affect': 2,
#  'the': 1,
#  'world': 1,
#  'of': 1,
#  'work': 1,
#  'blackcoffer': 3,
#  'insight': 2,
#  'a': 1,
#  'business': 3,
#  'close': 2,
#  'to': 1,
#  'help': 1,
#  'prevent': 2,
#  'transmission': 3,
#  'financial': 3,
#  'concern': 2,
#  'and': 1,
#  'job': 1,
#  'loss': 1,
#  'are': 2,
#  'one': 2,
#  'first': 1,
#  'human': 2,
#  'impact': 2,
#  'virus': 2,
#  'not': 1,
#  'knowing': 2,
#  'this': 1,
#  'pandemic': 3,
#  'play': 1,
#  'out': 1,
#  'also': 2,
#  'our': 1,
#  'economic': 4,
#  'physical': 3,
#  'mental': 2,
#  'well': 1,
#  'being': 1,
#  'despite': 3,
#  'fear': 1,
#  'community': 4,
#  'in': 1,
#  'many': 2,
#  'region': 2,
#  'have': 2,
#  'shown': 1,
#  'more': 2,
#  'altruistic': 3,
#  'response': 3,
#  'face': 2,
#  'crisis': 2,
#  'action': 2,
#  'which': 1,
#  'could': 1,
#  'country': 2,
#  'preparing': 3,
#  'for': 1,
#  'is': 1,
#  'decline': 3,
#  'china': 2,
#  'there': 2,
#  'now': 1,
# ...

# %%
len(syllables_per_word)
# Out:
# 471

# %%
def check():
    total_count = 0
    for i,j in syllables_per_word.items():
        
        total_count += j
    return total_count

# %%
check()
# Out:
# 949

# %% [markdown]
# #### 7	Personal Pronouns

# %%
def Personal_pronoun_count(words_list):
    list_of_words = ['I', 'we', 'my' ,'ours','us' ]
    list_words_counts = 0
    for words in words_list:
        if words in list_of_words:
            list_words_counts += 1
    return list_words_counts

# %%
Personal_pronoun_count(preprocessed_word)
# Out:
# 3

# %% [markdown]
# #### 8	Average Word Length

# %%
def Average_Word_Length(words):
    count = 0
    for i in words:
        for j in i:
            count += 1
        
    return count

# %%
round(Average_Word_Length(preprocessed_word)/len(preprocessed_word),0)
# Out:
# 5.0

# %%
df
# Out:
#              URL_ID                                                URL  \
# 0   blackassign0001  https://insights.blackcoffer.com/rising-it-cit...
# 1   blackassign0002  https://insights.blackcoffer.com/rising-it-cit...
# 2   blackassign0003  https://insights.blackcoffer.com/internet-dema...
# 3   blackassign0004  https://insights.blackcoffer.com/rise-of-cyber...
# 4   blackassign0005  https://insights.blackcoffer.com/ott-platform-...
# ..              ...                                                ...
# 94  blackassign0096  https://insights.blackcoffer.com/what-is-the-r...
# 95  blackassign0097  https://insights.blackcoffer.com/impact-of-cov...
# 96  blackassign0098  https://insights.blackcoffer.com/contribution-...
# 97  blackassign0099  https://insights.blackcoffer.com/how-covid-19-...
# 98  blackassign0100  https://insights.blackcoffer.com/how-will-covi...
#
#                                         article_words
# 0   Rising IT cities and its impact on the economy...
# ...

# %%
for i,j in enumerate(df['article_words']):
    print(len(j.split()))
# Out:
# 1242
# 1487
# 1077
# 1065
# 694
# 1864
# 1316
# 782
# 971
# 3644
# 1048
# 1447
# 1684
# 626
# 15
# 1241
# 1241
# 1177
# 1072
# 1735
# 9
# 1027
# 426
# 1395
# 572
# 1082
# 901
# 1345
# 1128
# 10
# 1422
# 1712
# 1662
# 1751
# 1311
# 746
# 735
# 2166
# 1986
# 1211
# 1239
# 1708
# 12
# 507
# 1819
# 966
# 734
# 330
# 1388
# 735
# 1944
# 685
# 384
# 1144
# 637
# 400
# 171
# 816
# 189
# 1163
# 554
# 1077
# 1731
# 1759
# 1473
# 892
# 1425
# 478
# 1601
# 992
# 1195
# 1214
# 1445
# 1043
# 1592
# 770
# 1198
# 1738
# 3466
# 1776
# 1513
# 6
# 12
# 1839
# 1771
# 1076
# 1800
# 974
# 1222
# 1108
# 13
# 196
# 1158
# 646
# 1131
# 1089
# 412
# 9
# 11

# %%
len(df['article_words'][10].splitlines())
# Out:
# 22

# %%
class data_ingestion:        
    
    def primary(self):
        try:
            data = pd.read_excel(os.path.join("Notebook/data","Input.xlsx"))
            #print(data.head())
            return data
        except Exception as e:
            print(f'Error {e}')

            
    def secondary(self):
        data = pd.read_excel('E:/For_Job/Blackcoffer/Code/Notebook/data/Input.xlsx')
        df = data.copy()  # Create a copy to avoid modifying the original DataFrame
        updated_list = []
        No_Matching_Data = []
        Blank_link = {}
        # Create an empty 'article_words' column
        #df['article_words'] = ''
        
        for i, url in enumerate(df['URL']):
            response_code = requests.get(url)
            soup = bs(response_code.text, 'html.parser')
            article_title = soup.find('title').text
            
            all_text_element = soup.find("div", class_="td-post-content tagdiv-type")

            if all_text_element is not None:
                all_text = all_text_element.get_text(strip=True, separator='\n')
                firstdata = all_text.splitlines()
            else:
                print(f"No matching element found in the HTML for URL: {url}")
                #firstdata = []        
                Blank_link[f"blackassign00{i+1}"] = url        
                Blank = {
                        'URL_ID' : f"blackassign00{i+1}" ,
                        'URL'    : url 
                        }
                No_Matching_Data.append(Blank)
                
             
            new_dataframe = {
                    "URL_ID": df["URL_ID"][i],
                    'URL' : url,
                    'article_words':f"{article_title}-{firstdata}"
                }    
            
            updated_list.append(new_dataframe)           
                

            filename = urllib.parse.quote_plus(url)
            file_path = 'E:\For_Job\Blackcoffer\Code\Text_files'
            space = " "
                
            with open(f"{file_path}\{filename}.txt", 'w+',encoding='utf-8') as file1:
                file1.writelines(article_title)
                file1.writelines(space)
                if firstdata is None:
                    firstdata = 'No data found'
                else:
                    file1.writelines(firstdata)
                
            # Update 'article_words' column for the current row
            #df.at[i, 'article_words'] = f"{article_title}-{firstdata}"

        #df.to_csv('E:\\For_Job\\Blackcoffer\\Code\\Notebook\\data\\final.csv', index=False)
        return pd.DataFrame(updated_list),No_Matching_Data
    
    
    def Handdle_Blank_link(self,blank_data):
        updated_list = []
        
        for item in blank_data:
            i = item['URL_ID']
            j = item['URL']
            
            response_code = requests.get(j)
            soup = bs(response_code.text, 'html.parser')
            article_title = soup.find('title').text
            
            alldiv = soup.find("div", class_="td_block_wrap tdb_single_content tdi_130 td-pb-border-top td_block_template_1 td-post-content tagdiv-type")

            if alldiv is not None:
                firstdata = alldiv.text
                
                filename = urllib.parse.quote_plus(j)
                file_path = 'E:\For_Job\Blackcoffer\Code\Text_files'
                space = " "
                    
                with open(f"{file_path}\{filename}.txt", 'w+') as file1:
                    file1.writelines(article_title)
                    file1.writelines(space)
                    file1.writelines(firstdata)
                
            
                updated_dict = {
                    'URL_ID': i,
                    'URL': j,
                    'article_words': f"{article_title} - {firstdata}"
                }
                
                
                updated_list.append(updated_dict)
                
            else:
                print(f"No data available for the link: {j}")


        df = pd.DataFrame(updated_list)
        return df

    def merged(self,df1,df2):
        merged_df = pd.merge(df1, df2, on=['URL_ID', 'URL'], how='outer')
        merged_df = merged_df.dropna()
        merged_df.reset_index(drop=True, inplace=True)
        
        merged_df.to_csv('E:\\For_Job\\Blackcoffer\\Code\\Notebook\\data\\final.csv', index=False)
        
        return merged_df
        



        
                
            
           
if __name__ == "__main__":
    obj = data_ingestion()
    obj1=obj.primary()
    df,remain_data=obj.secondary()
    update_df=obj.Handdle_Blank_link(remain_data)
    final=obj.merged(df,updated_df)
# Out:
# Error [Errno 2] No such file or directory: 'Notebook/data\\Input.xlsx'
# No matching element found in the HTML for URL: https://insights.blackcoffer.com/how-covid-19-is-impacting-payment-preferences/
# No matching element found in the HTML for URL: https://insights.blackcoffer.com/how-will-covid-19-affect-the-world-of-work-2/

# %%
df.shape
# Out:
# (10, 3)

# %%
remain_data
# Out:
# [{'URL_ID': 'blackassign009',
#   'URL': 'https://insights.blackcoffer.com/how-covid-19-is-impacting-payment-preferences/'},
#  {'URL_ID': 'blackassign0010',
#   'URL': 'https://insights.blackcoffer.com/how-will-covid-19-affect-the-world-of-work-2/'}]

# %%
for i,j in remain_data:
    #print(j)
    for ii in j:
      print(ii)
# Out:
# U
# R
# L
# U
# R
# L

# %%
for i in remain_data:
    print(i['URL'])
# Out:
# https://insights.blackcoffer.com/how-covid-19-is-impacting-payment-preferences/
# https://insights.blackcoffer.com/how-will-covid-19-affect-the-world-of-work-2/
